# %% [markdown]
# <a href="https://colab.research.google.com/github/tuthanbongdem/Pycharm/blob/main/REC__final_paddle_ocr_datn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# !python3 -m pip install paddlepaddle-gpu
# !pip install "paddleocr>=2.0.1"
# %cd /content/drive/MyDrive/OCR
# !pip install -r ./PaddleOCR/requirements.txt
# Out:
# Mounted at /content/drive
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.5/407.5 kB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 24.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 54.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 95.4 MB/s eta 0:00:00
# ...

# %%
# !python3 /content/drive/MyDrive/OCR/PaddleOCR/tools/train.py -c /content/drive/MyDrive/OCR/PaddleOCR/configs/rec/PP-OCRv4/en_PP-OCRv4_rec.yml
# -o Global.checkpoints=/content/drive/MyDrive/OCR/output/ch_PP-OCRv4/iter_epoch_240
# Out:
# [2024/08/23 08:05:50] ppocr INFO: Architecture :
# [2024/08/23 08:05:50] ppocr INFO:     Backbone :
# [2024/08/23 08:05:50] ppocr INFO:         name : PPLCNetV3
# [2024/08/23 08:05:50] ppocr INFO:         scale : 0.95
# [2024/08/23 08:05:50] ppocr INFO:     Head :
# [2024/08/23 08:05:50] ppocr INFO:         head_list :
# [2024/08/23 08:05:50] ppocr INFO:             CTCHead :
# [2024/08/23 08:05:50] ppocr INFO:                 Head :
# [2024/08/23 08:05:50] ppocr INFO:                     fc_decay : 1e-05
# [2024/08/23 08:05:50] ppocr INFO:                 Neck :
# [2024/08/23 08:05:50] ppocr INFO:                     depth : 2
# [2024/08/23 08:05:50] ppocr INFO:                     dims : 120
# [2024/08/23 08:05:50] ppocr INFO:                     hidden_dims : 120
# [2024/08/23 08:05:50] ppocr INFO:                     kernel_size : [1, 3]
# [2024/08/23 08:05:50] ppocr INFO:                     name : svtr
# [2024/08/23 08:05:50] ppocr INFO:                     use_guide : True
# ...

# %%
# !python3 -m pip install paddlepaddle
# !pip install "paddleocr>=2.0.1"
# %cd /content/drive/MyDrive/OCR
# !pip install -r ./PaddleOCR/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.5/407.5 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 16.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 41.8 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=71b12a37d345e82def592a7c0c8f595014252f685850ed4f899af509276f0a59
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...
# /content/drive/MyDrive/OCR
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 2.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: albumentations
# ...

# %%
# !python /content/drive/MyDrive/OCR/PaddleOCR/tools/export_model.py -c /content/drive/MyDrive/OCR/PaddleOCR/configs/det/ch_PP-OCRv4/ch_PP-OCRv4_det_student.yml  \
                             -o Global.pretrained_model=/content/drive/MyDrive/OCR/output/ch_PP-OCRv4/best_model/model \
                                Global.save_inference_dir=./inference/PP-OCRv4
# Out:
# [2024/08/18 08:59:15] ppocr INFO: load pretrain successful from /content/drive/MyDrive/OCR/output/ch_PP-OCRv4/best_model/model
# I0818 08:59:26.490005  2031 program_interpreter.cc:212] New Executor is Running.
# [2024/08/18 08:59:26] ppocr INFO: inference model is saved to ./inference/PP-OCRv4/inference
# [2024/08/18 08:59:26] ppocr INFO: Export inference config file to ./inference/PP-OCRv4/inference.yml

# %%
# !python3 /content/drive/MyDrive/OCR/PaddleOCR/tools/infer/predict_det.py  --det_algorithm="DB" \
                                   --use_gpu=False \
                                   --det_model_dir="./inference/PP-OCRv4"  \
                                   --image_dir="/content/drive/MyDrive/OCR/dataset/train/image/gt_01.jpg"
# Out:
# [2024/08/18 08:59:40] ppocr INFO: gt_01.jpg	[[[0.0, 0.0], [639.0, 0.0], [639.0, 639.0], [0.0, 639.0]]]
#
# [2024/08/18 08:59:40] ppocr INFO: 0 The predict time of /content/drive/MyDrive/OCR/dataset/train/image/gt_01.jpg: 0.41913866996765137
# [2024/08/18 08:59:40] ppocr INFO: The visualized image saved in ./inference_results/det_res_gt_01.jpg

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall -y paddlepaddle paddlepaddle-gpu
 -o Global.checkpoints=/content/drive/MyDrive/DATN_PADDLE_OCR/output/ch_PP-OCRv4/latest
# Out:
# Found existing installation: paddlepaddle 2.6.1
# Uninstalling paddlepaddle-2.6.1:
#   Successfully uninstalled paddlepaddle-2.6.1
# Found existing installation: paddlepaddle-gpu 2.6.1
# Uninstalling paddlepaddle-gpu-2.6.1:
#   Successfully uninstalled paddlepaddle-gpu-2.6.1

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
import shutil

source_folder = '/content/PaddleOCR'
destination_folder = '/content/drive/My Drive/DATN_PADDLE_OCR/PaddleOCR'

shutil.copytree(source_folder, destination_folder)
# Out:
# '/content/drive/My Drive/DATN_PADDLE_OCR/PaddleOCR'

# %%
import paddle
gpu_available  = paddle.device.is_compiled_with_cuda()
print("GPU available:", gpu_available)
# Out:
# /usr/local/lib/python3.10/dist-packages/paddle/base/framework.py:688: UserWarning: You are using GPU version Paddle, but your CUDA device is not set properly. CPU device will be used by default.
#   warnings.warn(
# GPU available: True
